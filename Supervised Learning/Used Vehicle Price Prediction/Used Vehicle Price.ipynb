# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import LabelEncoder
sns.set_theme(color_codes=True)

# %%
df = pd.read_csv('usedvehicle.csv')
df.head()
# Out:
#    Unnamed: 0  Year   Make Model Kilometres Body Type              Engine  \
# 0           0  2019  Acura   MDX   53052 km       SUV  V6 Cylinder Engine
# 1           1  2018  Acura   MDX   77127 km       SUV  V6 Cylinder Engine
# 2           2  2019  Acura   RDX   33032 km       SUV           2.0L 4cyl
# 3           3  2020  Acura   RDX   50702 km       SUV   4 Cylinder Engine
# 4           4  2021  Acura   RDX   67950 km       SUV   4 Cylinder Engine
#
#          Transmission Drivetrain        Exterior Colour Interior Colour  \
# 0   9 Speed Automatic        AWD   Majestic Black Pearl             Red
# 1   9 Speed Automatic        AWD  Modern Steel Metallic           Black
# 2  10 Speed Automatic        AWD    White Diamond Pearl           Black
# 3                 NaN        AWD   Platinum White Pearl           Black
# 4                 NaN        AWD        Apex Blue Pearl             Red
#
#    Passengers Doors         Fuel Type         City            Highway  Price
# 0         NaN   NaN               Gas  12.2L/100km  9.0L - 9.5L/100km  43880
# 1         NaN   NaN               Gas  12.6L/100km         9.0L/100km  36486
# 2         5.0     4  Premium Unleaded  11.0L/100km         8.6L/100km  40888
# 3         NaN   NaN               Gas  11.0L/100km         8.6L/100km  44599
# 4         NaN   NaN               Gas  11.3L/100km         9.1L/100km  46989

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)
df.shape
# Out:
# (24198, 16)

# %%
df.dtypes
# Out:
# Year                 int64
# Make                object
# Model               object
# Kilometres          object
# Body Type           object
# Engine              object
# Transmission        object
# Drivetrain          object
# Exterior Colour     object
# Interior Colour     object
# Passengers         float64
# Doors               object
# Fuel Type           object
# City                object
# Highway             object
# Price                int64
# dtype: object

# %%
# Remove rows with missing values in 'City' and 'Highway' columns in the original dataframe
df.dropna(subset=['City', 'Highway'], inplace=True)
# Extract all the characters before the first 'L' only if 'L' is present
mask = df['City'].str.contains('L')
df.loc[mask, 'City'] = df.loc[mask, 'City'].str.split('L', n=1, expand=True)[0]

mask = df['Highway'].str.contains('L')
df.loc[mask,'Highway'] = df.loc[mask, 'Highway'].str.split('L', n=1, expand=True)[0]

df.head()
# Out:
#    Year   Make Model Kilometres Body Type              Engine  \
# 0  2019  Acura   MDX   53052 km       SUV  V6 Cylinder Engine
# 1  2018  Acura   MDX   77127 km       SUV  V6 Cylinder Engine
# 2  2019  Acura   RDX   33032 km       SUV           2.0L 4cyl
# 3  2020  Acura   RDX   50702 km       SUV   4 Cylinder Engine
# 4  2021  Acura   RDX   67950 km       SUV   4 Cylinder Engine
#
#          Transmission Drivetrain        Exterior Colour Interior Colour  \
# 0   9 Speed Automatic        AWD   Majestic Black Pearl             Red
# 1   9 Speed Automatic        AWD  Modern Steel Metallic           Black
# 2  10 Speed Automatic        AWD    White Diamond Pearl           Black
# 3                 NaN        AWD   Platinum White Pearl           Black
# 4                 NaN        AWD        Apex Blue Pearl             Red
#
#    Passengers Doors         Fuel Type  City Highway  Price
# 0         NaN   NaN               Gas  12.2     9.0  43880
# 1         NaN   NaN               Gas  12.6     9.0  36486
# 2         5.0     4  Premium Unleaded  11.0     8.6  40888
# 3         NaN   NaN               Gas  11.0     8.6  44599
# 4         NaN   NaN               Gas  11.3     9.1  46989

# %%
# Remove non-numeric characters from the 'City' and 'Highway' columns
df['City'] = df['City'].str.replace('[^0-9.]', '', regex=True).astype(float)
df['Highway'] = df['Highway'].str.replace('[^0-9.]', '', regex=True).astype(float)
print(df.dtypes)
# Out:
# Year                 int64
# Make                object
# Model               object
# Kilometres          object
# Body Type           object
# Engine              object
# Transmission        object
# Drivetrain          object
# Exterior Colour     object
# Interior Colour     object
# Passengers         float64
# Doors               object
# Fuel Type           object
# City               float64
# Highway            float64
# Price                int64
# dtype: object

# %%
df.shape
# Out:
# (17835, 16)

# %%
df.dropna(subset=['Kilometres'], inplace=True)
df['Kilometres'] = df['Kilometres'].str.replace('km', '').astype(int)
df.dtypes
# Out:
# Year                 int64
# Make                object
# Model               object
# Kilometres           int32
# Body Type           object
# Engine              object
# Transmission        object
# Drivetrain          object
# Exterior Colour     object
# Interior Colour     object
# Passengers         float64
# Doors               object
# Fuel Type           object
# City               float64
# Highway            float64
# Price                int64
# dtype: object

# %%
df.shape
# Out:
# (17662, 16)

# %%
df.head()
# Out:
#    Year   Make Model  Kilometres Body Type              Engine  \
# 0  2019  Acura   MDX       53052       SUV  V6 Cylinder Engine
# 1  2018  Acura   MDX       77127       SUV  V6 Cylinder Engine
# 2  2019  Acura   RDX       33032       SUV           2.0L 4cyl
# 3  2020  Acura   RDX       50702       SUV   4 Cylinder Engine
# 4  2021  Acura   RDX       67950       SUV   4 Cylinder Engine
#
#          Transmission Drivetrain        Exterior Colour Interior Colour  \
# 0   9 Speed Automatic        AWD   Majestic Black Pearl             Red
# 1   9 Speed Automatic        AWD  Modern Steel Metallic           Black
# 2  10 Speed Automatic        AWD    White Diamond Pearl           Black
# 3                 NaN        AWD   Platinum White Pearl           Black
# 4                 NaN        AWD        Apex Blue Pearl             Red
#
#    Passengers Doors         Fuel Type  City  Highway  Price
# 0         NaN   NaN               Gas  12.2      9.0  43880
# 1         NaN   NaN               Gas  12.6      9.0  36486
# 2         5.0     4  Premium Unleaded  11.0      8.6  40888
# 3         NaN   NaN               Gas  11.0      8.6  44599
# 4         NaN   NaN               Gas  11.3      9.1  46989

# %%
# Add decimal point to Highway and City columns
df['Highway'] = df['Highway'] / 10
df['City'] = df['City'] / 10
df.head()
# Out:
#    Year   Make Model  Kilometres Body Type              Engine  \
# 0  2019  Acura   MDX       53052       SUV  V6 Cylinder Engine
# 1  2018  Acura   MDX       77127       SUV  V6 Cylinder Engine
# 2  2019  Acura   RDX       33032       SUV           2.0L 4cyl
# 3  2020  Acura   RDX       50702       SUV   4 Cylinder Engine
# 4  2021  Acura   RDX       67950       SUV   4 Cylinder Engine
#
#          Transmission Drivetrain        Exterior Colour Interior Colour  \
# 0   9 Speed Automatic        AWD   Majestic Black Pearl             Red
# 1   9 Speed Automatic        AWD  Modern Steel Metallic           Black
# 2  10 Speed Automatic        AWD    White Diamond Pearl           Black
# 3                 NaN        AWD   Platinum White Pearl           Black
# 4                 NaN        AWD        Apex Blue Pearl             Red
#
#    Passengers Doors         Fuel Type  City  Highway  Price
# 0         NaN   NaN               Gas  1.22     0.90  43880
# 1         NaN   NaN               Gas  1.26     0.90  36486
# 2         5.0     4  Premium Unleaded  1.10     0.86  40888
# 3         NaN   NaN               Gas  1.10     0.86  44599
# 4         NaN   NaN               Gas  1.13     0.91  46989

# %%
# iterate over columns with object datatype
for col in df.select_dtypes(include='object'):
    # count the unique number of values
    unique_count = df[col].nunique()
    # print the result
    print(f'The number of unique values in the "{col}" column is: {unique_count}')
# Out:
# The number of unique values in the "Make" column is: 39
# The number of unique values in the "Model" column is: 489
# The number of unique values in the "Body Type" column is: 26
# The number of unique values in the "Engine" column is: 951
# The number of unique values in the "Transmission" column is: 20
# The number of unique values in the "Drivetrain" column is: 6
# The number of unique values in the "Exterior Colour" column is: 1258
# The number of unique values in the "Interior Colour" column is: 15
# The number of unique values in the "Doors" column is: 4
# The number of unique values in the "Fuel Type" column is: 11

# %%
def fetch_model(text):
    if 'MDX' in text:
        return 'MDX'
    elif 'TSX' in text:
        return 'TSX'
    elif 'Grand' in text:
        return 'Grand'
    elif 'Civic' in text:
        return 'Civic'
    elif 'RDX' in text:
        return 'RDX'
    elif 'ILX' in text:
        return 'ILX'
    elif 'TLX' in text:
        return 'TLX'
    else:
        return 'Other Model'

# %%
df['Model'] = df['Model'].apply(fetch_model)

# %%
plt.figure(figsize=(10,5))
df['Model'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Model'>

# %%
df.drop(columns=['Exterior Colour', 'Interior Colour'], inplace=True)
df.shape
# Out:
# (17662, 14)

# %%
df.Make.unique()
# Out:
# array(['Acura', 'Alfa Romeo', 'Audi', 'Bentley', 'Volvo', 'BMW',
#        'Aston Martin', 'Buick', 'Cadillac', 'Chevrolet', 'Chrysler',
#        'Maserati', 'Porsche', 'Mazda', 'McLaren', 'Mercedes-Benz', 'MINI',
#        'Mitsubishi', 'Scion', 'Subaru', 'Dodge', 'Ferrari', 'Fiat',
#        'Ford', 'Genesis', 'GMC', 'Honda', 'Hummer', 'Hyundai', 'Infiniti',
#        'Jaguar', 'Jeep', 'Kia', 'Lamborghini', 'Nissan', 'Polestar',
#        'Rolls-Royce', 'Suzuki', 'Volkswagen'], dtype=object)

# %%
def segment_make(make):
    if make in ['Acura', 'Alfa Romeo', 'Audi', 'Bentley', 'BMW', 'Cadillac', 'Genesis', 'Infiniti', 'Jaguar', 'Lamborghini', 'Land Rover', 'Lexus', 'Lincoln', 'Maserati', 'McLaren', 'Mercedes-Benz', 'Porsche', 'Rolls-Royce', 'Tesla']:
        return 'Luxury'
    elif make in ['Buick', 'Chevrolet', 'Chrysler', 'Dodge', 'Ford', 'GMC', 'Jeep', 'Ram']:
        return 'Mainstream'
    elif make in ['Ferrari', 'Lotus']:
        return 'Sports'
    elif make in ['Honda', 'Hyundai', 'Kia', 'Mazda', 'Mitsubishi', 'Nissan', 'Subaru', 'Toyota', 'Volkswagen']:
        return 'Value'
    else:
        return 'Other'

# %%
df['Make'] = df['Make'].apply(segment_make)

# %%
plt.figure(figsize=(10,5))
df['Make'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Make'>

# %%
df['Body Type'].unique()
# Out:
# array(['SUV', 'Sedan', 'Coupe', 'Convertible', 'Hatchback', nan, 'Wagon',
#        'Roadster', 'Station Wagon', 'Truck', 'Truck Extended Cab',
#        'Extended Cab', 'Crew Cab', 'Regular Cab', 'Compact',
#        'Truck Crew Cab', 'Super Cab', 'Minivan', 'Cabriolet',
#        'Van Regular', 'Super Crew', 'Quad Cab', 'Truck Super Cab',
#        'Van Extended', 'Truck Double Cab', 'Truck King Cab',
#        'Truck Long Crew Cab'], dtype=object)

# %%
# Define the body type segments
suv = ['SUV']
sedan = ['Sedan', 'Coupe', 'Convertible']
hatchback = ['Hatchback']
wagon = ['Wagon', 'Station Wagon']
truck = ['Truck', 'Truck Extended Cab', 'Extended Cab', 'Crew Cab',
         'Regular Cab', 'Truck Crew Cab', 'Super Cab', 'Quad Cab',
         'Truck Super Cab', 'Truck Double Cab', 'Truck King Cab',
         'Truck Long Crew Cab']
van = ['Van Regular', 'Van Extended']
minivan = ['Minivan']
roadster = ['Roadster']
cabriolet = ['Cabriolet']
super_crew = ['Super Crew']
compact = ['Compact']

# Create a dictionary to map each body type to its corresponding segment
body_type_segments = {}
for body_type in df['Body Type'].unique():
    if body_type in suv:
        body_type_segments[body_type] = 'SUV'
    elif body_type in sedan:
        body_type_segments[body_type] = 'Sedan'
    elif body_type in hatchback:
        body_type_segments[body_type] = 'Hatchback'
    elif body_type in wagon:
        body_type_segments[body_type] = 'Wagon'
    elif body_type in truck:
        body_type_segments[body_type] = 'Truck'
    elif body_type in van:
        body_type_segments[body_type] = 'Van'
    elif body_type in minivan:
        body_type_segments[body_type] = 'Minivan'
    elif body_type in roadster:
        body_type_segments[body_type] = 'Roadster'
    elif body_type in cabriolet:
        body_type_segments[body_type] = 'Cabriolet'
    elif body_type in super_crew:
        body_type_segments[body_type] = 'Super Crew'
    elif body_type in compact:
        body_type_segments[body_type] = 'Compact'
    else:
        body_type_segments[body_type] = 'Other'

# Map the body type segments to the dataframe
df['Body Type'] = df['Body Type'].map(body_type_segments)

# %%
plt.figure(figsize=(10,5))
df['Body Type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Body Type'>

# %%
df['Transmission'].unique()
# Out:
# array(['9 Speed Automatic', '10 Speed Automatic', nan, 'Automatic',
#        '6 Speed Manual', '8 Speed Automatic', '6 Speed Automatic',
#        '8 Speed Automatic with auto-shift', '5 Speed Automatic',
#        '5 Speed Manual', '4 Speed Automatic', 'Manual',
#        '7 Speed Automatic with auto-shift',
#        '6 Speed Automatic with auto-shift', 'Sequential',
#        '7 Speed Automatic', 'CVT', '1 Speed Automatic', '7 Speed Manual',
#        '5 Speed Automatic with auto-shift', 'F1 Transmission'],
#       dtype=object)

# %%
def segment_transmission(transmission):
    if transmission in ['Automatic', 'CVT', '1 Speed Automatic']:
        return 'Automatic'
    elif transmission in ['6 Speed Manual', '5 Speed Manual', '7 Speed Manual']:
        return 'Manual'
    elif transmission in ['9 Speed Automatic', '10 Speed Automatic', '8 Speed Automatic', '7 Speed Automatic', '5 Speed Automatic', '4 Speed Automatic']:
        return 'Traditional Automatic'
    elif transmission in ['8 Speed Automatic with auto-shift', '6 Speed Automatic with auto-shift', '7 Speed Automatic with auto-shift', '5 Speed Automatic with auto-shift']:
        return 'Automated Manual'
    elif transmission == 'Sequential':
        return 'Semi-Automatic'
    elif transmission == 'F1 Transmission':
        return 'Automated Single-Clutch'
    else:
        return 'Unknown'

df['Transmission'] = df['Transmission'].apply(segment_transmission)

# %%
plt.figure(figsize=(10,5))
df['Transmission'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Transmission'>

# %%
df.drop(columns=['Transmission'], inplace=True)
df.shape
# Out:
# (17662, 13)

# %%
df.head()
# Out:
#    Year    Make Model  Kilometres Body Type              Engine Drivetrain  \
# 0  2019  Luxury   MDX       53052       SUV  V6 Cylinder Engine        AWD
# 1  2018  Luxury   MDX       77127       SUV  V6 Cylinder Engine        AWD
# 2  2019  Luxury   RDX       33032       SUV           2.0L 4cyl        AWD
# 3  2020  Luxury   RDX       50702       SUV   4 Cylinder Engine        AWD
# 4  2021  Luxury   RDX       67950       SUV   4 Cylinder Engine        AWD
#
#    Passengers Doors         Fuel Type  City  Highway  Price
# 0         NaN   NaN               Gas  1.22     0.90  43880
# 1         NaN   NaN               Gas  1.26     0.90  36486
# 2         5.0     4  Premium Unleaded  1.10     0.86  40888
# 3         NaN   NaN               Gas  1.10     0.86  44599
# 4         NaN   NaN               Gas  1.13     0.91  46989

# %%
# iterate over columns with object datatype
for col in df.select_dtypes(include='object'):
    # count the unique number of values
    unique_count = df[col].nunique()
    # print the result
    print(f'The number of unique values in the "{col}" column is: {unique_count}')
# Out:
# The number of unique values in the "Make" column is: 5
# The number of unique values in the "Model" column is: 8
# The number of unique values in the "Body Type" column is: 12
# The number of unique values in the "Engine" column is: 951
# The number of unique values in the "Drivetrain" column is: 6
# The number of unique values in the "Doors" column is: 4
# The number of unique values in the "Fuel Type" column is: 11

# %%
# list of categorical variables to plot
cat_vars = ['Make', 'Model', 'Body Type', 'Drivetrain', 'Doors', 'Fuel Type'] 

# create figure with subplots
fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(20, 10))
axs = axs.ravel()

# create barplot for each categorical variable
for i, var in enumerate(cat_vars):
    sns.barplot(x=var, y='Price', data=df, ax=axs[i], estimator=np.mean)
    axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=90)

# remove the eighth subplot
fig.delaxes(axs[7])

# adjust spacing between subplots
fig.tight_layout()

# show plot
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2528\3657782626.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=90)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2528\3657782626.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=90)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2528\3657782626.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=90)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2528\3657782626.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=90)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2528\3657782626.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=90)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2528\3657782626.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=90)

# %%
num_vars = ['Passengers', 'City', 'Highway']

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(20, 10))
axs = axs.flatten()

for i, var in enumerate(num_vars):
    sns.boxplot(x=var, data=df, ax=axs[i])

fig.tight_layout()

plt.show()

# %%
num_vars = ['Passengers', 'City', 'Highway']

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(20, 10))
axs = axs.flatten()

for i, var in enumerate(num_vars):
    sns.violinplot(x=var, data=df, ax=axs[i])

fig.tight_layout()

plt.show()

# %%
num_vars = ['Passengers', 'City', 'Highway']

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(20, 10))
axs = axs.flatten()

for i, var in enumerate(num_vars):
    sns.scatterplot(x=var, y='Price', hue='Make', data=df, ax=axs[i])

fig.tight_layout()

plt.show()

# %%
sns.set_style("darkgrid")
sns.set_palette("Set2")

sns.lineplot(x='Year', y='Price', hue='Make', data=df, ci=None, estimator='mean', alpha=0.7)

plt.title("Price by Year Sold and Car Type")
plt.xlabel("Year")
plt.ylabel("Price")

plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2528\2920840915.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='Year', y='Price', hue='Make', data=df, ci=None, estimator='mean', alpha=0.7)

# %%
check_missing = df.isnull().sum() * 100 / df.shape[0]
check_missing[check_missing > 0].sort_values(ascending=False)
# Out:
# Passengers    46.342430
# Doors         19.805232
# Drivetrain     2.276073
# Engine         0.016986
# dtype: float64

# %%
# Loop over each column in the DataFrame where dtype is 'object'
for col in df.select_dtypes(include=['object']).columns:
    
    # Print the column name and the unique values
    print(f"{col}: {df[col].unique()}")
# Out:
# Make: ['Luxury' 'Other' 'Mainstream' 'Value' 'Sports']
# Model: ['MDX' 'RDX' 'TLX' 'TSX' 'ILX' 'Other Model' 'Grand' 'Civic']
# Body Type: ['SUV' 'Sedan' 'Hatchback' 'Other' 'Wagon' 'Roadster' 'Truck' 'Compact'
#  'Minivan' 'Cabriolet' 'Van' 'Super Crew']
# Engine: ['V6 Cylinder Engine' '2.0L 4cyl' '4 Cylinder Engine' '3.5L' '3.5L 6cyl'
#  'Intercooled Turbo Premium Unleaded I-4 2.0 L/122'
#  'V6 Cylinder Engine 3.5L' '6 Cylinder' '2.4L 4 Cylinder Engine' '3.5'
#  '4 Cylinder Engine 2.4L' 'Premium Unleaded I-4 2.4 L/144' 'V-6 cyl'
#  '3.5L V6 Cylinder Engine' 'I-4 cyl' '6' '2.0L 4 Cylinder Engine'
#  '4 Cylinder Engine 2.0L' 'Premium Unleaded V-6 3.5 L/212'
#  'V6 Cylinder Engine 3.0L' '3.5L V6 F SOHC 24V' '2.4' '3.7' '3.7L 6cyl'
#  '2' '1.7L L4 SOHC 16V' '4 Cylinder Engine 2.3L' '2.4L 4cyl' '4 CYL'
#  '201HP 2.4L 4 Cylinder Engine' '3.5L SOHC'
#  '3.5L SOHC 24-Valve VTEC V6 -inc: Aluminum-alloy' '2.5L'
#  '3.2L V6 258HP 233FT. LBS.' '2.3' '2.9L 6cyl' 'I4' '4 Cylinder'
#  '2.0L L4 DOHC 16V' '8 Cylinder Engine'
#  'Intercooled Turbo Premium Unleaded I-4 2.0 L/121' '2.0L 4-Cyl Engine'
#  '3' '3.0L TDI DOHC Direct-Injection V6 -inc: Turbocharg'
#  ': 2.0 TFSI 4 Cylinder 252 HP' '2.0L 4-Cylinder TFSI' '3.0L'
#  '3.0L V6 Cylinder Engine' 'Intercooled Turbo Gas/Electric I-4 1.4 L/85'
#  '3.0L 6cyl' '220HP 2.0L 4 Cylinder Engine'
#  'Intercooled Turbo Gas w/ Electric Assist V-6 3.0 L'
#  'Intercooled Turbo Regular Unleaded I-4 2.0 L/121' '2L TURBO 4cyl.' '. L'
#  '2.0L' 'Intercooled Turbo Premium Unleaded V-6 3.0 L/183'
#  'Moteur à 10 cylindres 5.2L' '10 Cylinder Engine 5.2L' '5 Cylinder'
#  '5 Cylinder Engine' '4.0L 8 Cylinder Engine' '4.2' '2.9'
#  'V6 Cylinder Engine 2.9L' 'Intercooled Turbo Gas/Electric V-6 3.0 L/183'
#  '8 Cylinder' 'Twin Turbo Premium Unleaded V-6 2.9 L/177' 'V8'
#  '2.0 TFSI 4-Cyl 200hp Engine' '3.0t' '3.0L TFSI V6 333hp Engine'
#  '3.0L V6 DOHC 24V' '4.2L' '3L TURBO 6cyl.' '3L 6cyl.' '3.2'
#  '2.0L L4 DOHC 24V' '2.9L turbo 6cyl.' 'V8 Twin Turbo' '10 Cylinder'
#  '4.2L 8cyl' '2.0L L4 DOHC 16V TURBO' 'Moteur V6 2.9L' '2.0L Turbo 4 Cyl.'
#  '6cyl' '2.5L L5 DOHC 20V' '3.0L V6 DOHC 24V TURBO' '3.2 L'
#  '3.0T Supercharged' '2.0T' '3.0 V6 Supercharge' '4.0L 435.0hp'
#  '3.0L Turbo' '3.0L V6 TFSI DOHC' '2.0L I4 F DOHC 16V' '2L 4cyl.'
#  'V-8 cyl' '1.8' '12 Cylinder' 'W12' '12 Cylinder Engine'
#  'V12 Cylinder Engine' '8 Cylinder Engine 4.0L' '4.0L' '6.0L'
#  '6.0L 12cyl DOHC Turbo' '2.5' '2.0L -TURBO' 'Straight 6 Cylinder Engine'
#  '3.2L' '2.0L-TURBO' '3.0L-TURBO' '3.0L Turbo Inline-6 Gas'
#  'Straight 6 Cylinder' '2.0L 4-Cyl Twinpower Turbo Engine'
#  'Straight 6 Cylinder Engine 3.0L' '2.0-liter turbocharged I-4' '4.4'
#  'I-6 cyl' '3.0L Straight 6 Cylinder Engine' '3.0L Straight 6-Cyl Engine'
#  '8 Cylinder Engine 4.4L' 'Intercooled Turbo Gas/Electric I-4 2.0 L/122'
#  '2.0L I4 TwinPower Turbo' '4.4L 8-Cyl Engine'
#  'Intercooled Turbo Gas/Electric I-6 3.0 L/183' '4.4L'
#  'Twin Turbo Premium Unleaded V-8 4.4 L/268' ': 4.4L Twinscroll Turbo V8'
#  '4.4L 8 Cylinder Engine' '4.4L 8cyl' 'Moteur à 6 cylindres droits 3.0L'
#  '2.0L Twin Power Turbo In-Line 4-Cyl Engine' '3 Cylinder Engine'
#  '2.0L DOHC DI 16-Valve Twinpower Turbo I4 Engine'
#  '3.2L DOHC 333hp 24-Valve I6 M Engine' '10 Cylinder Engine'
#  'Intercooled Turbo Premium Unleaded I-6 3.0 L/182' '4' '4.0L 8cyl' '4.8'
#  '3.0L I6 DOHC 24V TwinPower Turbo' '248HP 2.0L 4 Cylinder Engine'
#  '3.0L L6 DOHC 24V' 'STRAIGHT 6 CYLINDER ENGINE'
#  '300HP 3.0L Straight 6 Cylinder Engine'
#  '3.0L DOHC I-6 24V TwinPower Turbo' '4.4L V8 DOHC 32V' '3.0L I6'
#  '4.4L V8 4-OHC 32V' '6 Cylinder Engine' 'N55 TWIN TURBO' '2.0L 241.0hp'
#  '4.4L V8 Twin Turbo' '3.0L 255.0hp' '2.0L 4cyl Turbo' '2.0L Turbo'
#  '3L Turbo' '1.4L 4cyl' 'Gas V6 3.6L/217' '4 Cylinder Engine 1.4L'
#  '155HP 1.3L 3 Cylinder Engine' '3.6' 'Turbocharged 1.3/' '3.6L 6cyl'
#  'ECOTEC 1.3L Turbo' '2.4L' '1.3L 3cyl' '1.4L GAS SAVER'
#  'ECOTEC 1.3L TURBO' 'ECOTEC 1.4L I4 SMPI DOHC Turbocharged VVT'
#  '1.3L SIDI DOHC VVT TURBO' '6.2' '237HP 2.0L 4 Cylinder Engine' '6.2L V8'
#  '2.0L Turbo I4 DI DOHC VVT Engine' 'Gas V8 6.2L/376'
#  '8 Cylinder Engine 6.2L' '6.2L 8cyl' '4.6' '3.6L V6 DI VVT'
#  '2.0L Turbocharged' '6.2L Variable Valve Timing V8 SIDI' '2.7L 4cyl'
#  '3.6L 6cyl.' '2.0L I4 Turbocharged DOHC 16V LEV3-SULEV30 237hp' '3.6L V6'
#  '1.4' '5.3L 8cyl' 'Turbocharged Gas I4 1.4L/' 'Gas I4 2.4/145'
#  'Gas V6 4.3L/' 'Turbocharged Gas I4 1.5L/92' '4 Cylinder Engine 1.5L'
#  'I-3 cyl' 'V6 Cylinder Engine 3.6L' 'V6' '2.7L TURBO HIGH-OUTPUT'
#  'DURAMAX 3.0L TURBO-DIESEL' '5.3 L' '8' '1.4L 4-Cyl Engine' '4.3'
#  '1.5L TURBO DOHC' '455HP 6.2L 8 Cylinder Engine' 'Gas I3 1.3L/'
#  '3.6L DOHC DI V6 W/VVT' '3.6L DOHC SIDI V6 W/VVT'
#  'V6 Cylinder Engine 3.4L' '4 Cylinder Engine 1.8L' '1.4L I4 F DOHC 16V'
#  '1.5' 'Gas I4 1.4L/85.4' 'Turbocharged Gas I4 2.7L/166'
#  '1.3L L3 DOHC 12V' '160HP 1.5L 4 Cylinder Engine'
#  '175HP 1.5L 4 Cylinder Engine' '310HP 2.7L 4 Cylinder Engine'
#  '5.3L Liter V8 Vortec LMG Engine' '355HP 5.3L 8 Cylinder Engine'
#  'Gas V8 5.3L/325' '305HP 3.0L Straight 6 Cylinder Engine'
#  'Turbocharged Gas I4 1.5L/' '420HP 6.2L 8 Cylinder Engine' '1.5L DOHC'
#  '3.6L V6 F DOHC 24V' 'ECOTEC 2.4L FLEX FUEL I4 175HP'
#  '2.4L I4 182HP 172FT. LBS.' '1.4L' '153HP 1.4L 4 Cylinder Engine'
#  '5.3L ECOTEC3 V8' '1.5L 4cyl' '3.6L' '3.6L V6 SIDI DOHC VVT'
#  '5.3L V8 OHV 16V' 'EcoTec3 5.3L V8' '5.3L 8 Cyl.' '1.4L DOHC'
#  '1.4L 4 CYL' '2.0L Turbo Diesel' '5.3' '1.5L' '2.7' '2.7L Turbo'
#  '2.7L TURBO I4' '2.7L TURBO I4 ENGINE' '6.2L ECOTEC3 V8' 'Gas V6 3.6L/'
#  'ECOTEC 1.4L TURBO I4 138HP 148' '1.5L TURBO 4cyl.'
#  'Turbocharged Gas I4 1.5L/91' '7.0L 8cyl' '5.3L 8cyl.' '2.7L TURBO 4cyl.'
#  '6.2L 8cyl.' '3.6L V6 252HP 251FT. LBS.' '6.0L 8cyl' '5.7L 8Cyl'
#  '1.5L Turbo' '1.3L Turbo' '3.6L V6 DI' nan
#  'ECOTEC 1.8L FLEX FUEL I4 138HP' '4.3l' '2.0L 151.0hp' '3.6L V6 SIDI VVT'
#  '6.2L' '1.2' 'Regular Unleaded V-6 3.6 L/220' '3.6L Pentastar VVT V6'
#  '3.6L Pentastar VVT V6 w/ESS' '4.0L 6cyl' '3.6L V6 24V VVT' '3.6 L'
#  '3.6L Pentastar VVT V6 Hybrid' '3.6L V6 Hybrid Engine'
#  '3.6L V6 24V MPFI DOHC' '2.4L I4 173HP 166FT. LBS.' '4.7'
#  '3.8L V8 Twin Turbocharged' '3.0L V6' '433HP 4.7L 8 Cylinder Engine'
#  '4.7L 8cyl' '3.4' 'Flat 6 Cylinder Engine' '8 Cylinder Engine 4.8L'
#  'Twin Turbo Premium Unleaded V-6 3.0 L/183' '2.9L V6 DOHC 24V' '2.9L'
#  '3.8' 'Twin Turbo Premium Unleaded H-6 3.0 L/182' '2.0L I4 Turbocharged'
#  'Flat 6 Cylinder' '3.8L' '3.4L 6cyl' '3.6L V6 DOHC 24V TWIN-TURBO'
#  '370HP 3.0L Flat 6 Cylinder Engine' '3.8L 6cyl' '2.5L 4cyl'
#  '2.5L TURBO 4cyl.' 'V6 Cylinder Engine 3.7L'
#  '148HP 2.0L 4 Cylinder Engine' 'HXXK89'
#  '2.5L SKYACTIV-G DOHC 16-Valve 4-Cylinder' 'HXTK89' '2L'
#  '2.5L 4-Cyl Engine' '187HP 2.5L 4 Cylinder Engine' 'NXSN89' 'DVSL81'
#  '2.5L L4 DOHC 16V' 'SKYACTIVÂ®-G 2.0L 4-Cylinder DOHC 16V'
#  '186HP 2.5L 4 Cylinder Engine' 'NVSN81' '4 Cylinder Engine 2.5L'
#  'Regular Unleaded I-4 2.5 L/152' 'HXTK80' 'I4 Turbo' 'NXSN81' 'QXLM89'
#  '227HP 2.5L 4 Cylinder Engine' '2.5L 4cyl.' 'QXKM88'
#  'Intercooled Turbo Regular Unleaded I-4 2.5 L/152'
#  '181HP 2.0L 4 Cylinder Engine' 'L2EK81' '155HP 2.0L 4 Cylinder Engine'
#  '0' 'HXSK88' 'SVSN89' 'SXSN89' 'SXTN80' 'DXSN80' 'ZVSL80' 'NXSN80'
#  'ZXSL82' 'D4TY80' 'NXTL86' 'SVTN89' 'DXTN89' 'SVTN60' 'DVTN80'
#  '2.5L SKYACTIV-G DOHC 16-Valve I4'
#  ': 2.5L SKYACTIV-G DOHC 16-Valve I4 -inc: cylinder' 'HVSK86'
#  '2.5L SKYACTIV-G DOHC 16-VALVE I4' '2.3L INLINE 4 DOUBLE OVERHEAD' '3.7L'
#  'SKYACTIVÂ® 2.5L 4-Cylinder DOHC 16V' '2.0 L 4CYL'
#  '2.5L I4 170HP 167FT. LBS.' '2.0L I4 148HP 135FT. LBS.'
#  'SKYACTIV-G 2.5L I4 184HP 185FT' '191HP 2.5L 4 Cylinder Engine'
#  '2.5L I4 161HP 161FT. LBS.'
#  'SKYACTIV-G 2.0L DOHC 16-Valve I4 -inc: Induction S'
#  'Twin Turbo Premium Unleaded V-8 3.8 L/232' '5.5'
#  '8 Cylinder Engine 4.6L' '2.0L I4 DOHC Turbocharged' 'WIP SERVICE'
#  '2.0L TURBOCHARGED' 'Turbo' '2.0L I4 DI Turbocharged' '4cyl'
#  '4.7L 8 Cylinder Engine' '2.0L I4 DOHC' 'HOUSE DEMO' '4.7L' '5.5L'
#  'C43A 4M' '8 Cylinder Engine 5.5L' "DEMO RDR'D 2/28" 'SHOWROOM' 'detail'
#  'DETAIL' '2.1' '4 cyl' 'detail|AT TNT'
#  'Intercooled Turbo Diesel V-6 3.0 L/182' '5.5L 8cyl' 'HOLD FOR request'
#  '5.5L Twin-Turbo V8 Engine' '5'
#  'Twin Turbo Premium Unleaded V-8 4.0 L/243' 'Showroom' 'WIP DETAIL'
#  'Premium Unleaded I-4 1.6 L/98'
#  'Intercooled Turbo Premium Unleaded I-3 1.5 L/91' '2.0L TWIN TURBO'
#  '3 Cylinder Engine 1.5L' 'Intercooled Turbo Gas/Electric I-3 1.5 L/91'
#  '1.6' '1.5L 3cyl' '1.6L 4cyl' '1.6L 4 Cylinder Engine'
#  'Turbocharged Gas I4 1.6L/98' '1.6l'
#  'Intercooled Turbo Premium Unleaded I-4 1.6 L/98'
#  '181HP 1.6L 4 Cylinder Engine' '3 Cylinder' '1.5L TURBO' '1.6L 118.0hp'
#  '2.4L 4cyl.' '1.2L 3cyl'
#  'Intercooled Turbo Regular Unleaded I-4 1.5 L/91'
#  'Regular Unleaded I-4 2.4 L/144' '2.5L 4-Cylinder DOHC' 'v6' '2.4L SOHC'
#  '2.0L I4 DOHC 16V MIVEC' '2.4L SOHC I4 MIVEC 16 Valve'
#  '2.4L I4 168HP 167FT. LBS.' '2.0L I4 148HP 146FT. LBS.'
#  '3 Cylinder Engine 1.2L' '2.0L DOHC MIVEC I4'
#  '1.5L DOHC MIVEC 4-Cylinder Turbo' '2.4L DOHC MIVEC I4'
#  '2.5L DOHC 4-Cylinder Direct Injection' '2.4L DOHC I4 MIVEC'
#  '2.0L I4 148HP 145FT. LBS.' '2.4L 166.0hp' '2.0L 152.0hp'
#  '2.4L L4 DOHC 16V' 'H-4 cyl' '2.0L H4' '2.5L 4 Cylinder Engine'
#  'Regular Unleaded H-4 2.5 L/152'
#  'Intercooled Turbo Regular Unleaded H-4 2.4 L/146' '2.5L DOHC'
#  'Flat 6 Cylinder Engine 3.6L' '2.0L H4 DOHC 16V'
#  'Regular Unleaded H-4 2.0 L/122' '175HP 2.5L 4 Cylinder Engine'
#  '2.0L Boxer H4 DOHC 16V' '2.4L DOHC 16V' '2.5L Boxer H4 DOHC 16V'
#  '2.0L H4 148HP 145FT. LBS.' '2.0L 16V DOHC'
#  'Intercooled Turbo Premium Unleaded H-4 2.5 L/150' '2.5L H4 F DOHC 16V'
#  '2.5 - 4Cyl.' '5.7L HEMI VVT V8 w/FuelSaver MDS' '3.6L V6 DOHC 24V'
#  '8 Cylinder Engine 5.7L' '8cyl' 'SRT HEMI 6.4L V8 with Fuelsaver MDS'
#  '6.2L 8 Cylinder Engine' 'LDDS48' '5.7L HEMI VVT V8 W/FUELSAVER MDS'
#  '6.4L 8cyl' '6.4L SRT HEMI V8 w/FuelSaver MDS' '3.5L V6'
#  'HEMI 5.7L V8 Multi Displacement VVT' 'HEMI 5.7L V8 VVT' '3.3' 'V10 SFI'
#  'SC SRT HEMI V8' '8.4L 10 Cylinder Engine' '8.4L 10cyl' '5.7'
#  'PENTASTAR 3.6L V6 283HP 260FT.' 'V6 283HP 260FT. LBS.'
#  '283HP 3.6L V6 Cylinder Engine' '3.6L V6 Flex Fuel 24V VVT'
#  'Pentastar 3.6L V6 VVT' '3.6L PENTASTAR VVT V6 W/ESS'
#  '6.2L Supercharged HEMI V8 SRT' '6.2L V8 Supercharged' '6 CYL V6'
#  'SRT HEMI 6.4L V8 MDS' '8.4L V10 SFI' '5.7L V8 16V MPFI OHV'
#  '3.5L V6 235HP 232FT. LBS.'
#  'Intercooled Turbo Premium Unleaded I-4 2.0 L'
#  'Regular Unleaded V-8 5.7 L/345' '6.2L SRT HEMI V8 Supercharged' '3.5 L'
#  '97000' 'Premium Unleaded V-8 6.4 L/392'
#  '6.2L V8 16V MPFI OHV Supercharged' '6.3L' '4.3L 8cyl'
#  'Twin Turbo Premium Unleaded V-8 3.9 L/235' '3.9L'
#  ': Twin-Scroll 2.0L EcoBoost -inc: auto start-stop'
#  '231HP 2.0L 4 Cylinder Engine' '2.0L ECOBOOST GTDI I-4'
#  '1.5L 4-Cyl Engine' '1.5L I4' '2.7L 6cyl'
#  'Regular Unleaded I-4 2.0 L/122'
#  'Intercooled Turbo Regular Unleaded I-4 1.5 L/92'
#  ': 2.0L EcoBoost GTDI I-4 -inc: steering wheel-moun' '1.5L EcoBoost'
#  '1.5L L4 DOHC 16V' 'E: TWIN-SCROLL 2.0L I4 ECOBOOST'
#  'Regular Unleaded V-6 3.5 L/213' 'Gas/Electric I-4 2.0 L/122'
#  'Gas I4 2.3L/140' '2.3L 4cyl' '5.0L Ti-VCT V8' 'ENG: 3.5L TI-VCT V6'
#  'E: 2.7L V6 ECOBOOST' 'E: 2.3L I-4 ECOBOOST' '2.3L I4 EcoBoost'
#  '5.2L 8 Cyl' ': 2.0L EcoBoost -inc: auto start-stop technology'
#  'Regular Unleaded 2.7 L EcoBoost' '8 Cylinder Engine 5.0L'
#  'Electric Motor' '3.5L TI-VCT V6' '5.2' '2.0L Ecoboost Gtdi I-4 Engine'
#  '1.5L Ecoboost Gtdi Sigma Engine'
#  'Intercooled Turbo Premium Unleaded I-4 2.3 L/140'
#  ': 1.5L EcoBoost -inc: auto-start-stop technology' '3.5L V6 Ti-VCT'
#  '2.3L 4 Cylinder Engine' '1.5L I3' '5.0L V8'
#  'Intercooled Turbo Regular Unleaded I-4 2.3 L/140'
#  'Intercooled Turbo Regular Unleaded I-4 2.0 L/122'
#  '3.5L POWERBOOST HYBRID' '1' 'Moteur Ã\xa0 8 cylindres 5.2L'
#  'Intercooled Turbo Regular Unleaded I-3 1.5 L/91' '2.0L I4 Ti-VCT GDI'
#  ': 3.5L V6 EcoBoost -inc: auto start-stop technolog' '5.4' '1.5L L3'
#  '3.3L Ti-VCT V6' '480HP 5.0L 8 Cylinder Engine'
#  ': 5.0L Ti-VCT V8 -inc: port fueled direct injectio'
#  'Regular Unleaded 3.5 L EcoBoost' 'v8' '5.0L 8cyl' '2.0 L/122'
#  '1.0L 3cyl' 'Twin Turbo Regular Unleaded V-6 2.7 L/164' '2.3L ECOBOOST'
#  '3.0L FLEX FUEL V6 240HP 223FT.' 'DURATEC 2.5L I4 171HP 171FT. L'
#  'ECOBOOST 1.6L TURBO I4 178HP 1' '2.3L ECOBOOST I-4'
#  '245HP 2.0L 4 Cylinder Engine'
#  '2.0L Ti-VCT GDI I-4 -inc: auto start-stop technolo'
#  'EcoBoost 2.0L I4 GTDi DOHC Turbocharged VCT'
#  '2.3L 4-Cylinder DGI Turbocharged DOHC'
#  'EcoBoost 2.3L I4 GTDi DOHC Turbocharged VCT' '3.3L V6 DOHC 24V'
#  '3.3L PFDI' '5.0L V8 OHV 16V' '2.3L I-4 ECOBOOST' '2.7L V6 EcoBoost'
#  '1.5L ECOBOOST' '3.5L V6 EcoBoost' '2.3L 4-Cylinder Turbocharged DOHC'
#  '2.7L V6 24V PDI DOHC Twin Turbo' '2.7L V6 ECOBOOST'
#  '3.0L V6 24V GDI DOHC Twin Turbo' 'ELECTRIC'
#  '3.5L V6 24V PDI DOHC Twin Turbo Hybrid' '5.2L 8cyl'
#  '2.5L I4 175HP 172FT. LBS.' '2.0L I4 FI DO'
#  '2.0L IVCT ATKINSON CYCLE I-4 HYBRID' '3.5L V6 Ecoboost'
#  'Moteur Ã\xa0 8 cylindres 5.0L' '1.6L L4 DOHC 16V'
#  'TWIN-SCROLL 2.0L I4 ECOBOOST' '2.0L TI-VCT GDI I-4'
#  '188HP 2.0L 4 Cylinder Engine' '3.5L V6 DOHC 24V'
#  '1.5L EcoBoost? Engine with Auto Start-Stop Technol'
#  '2.3L I4 16V GDI DOHC Turbo' '2.5L IVCT ATKINSON CYCLE I-4 HYBRID'
#  '1.5L I3 Turbo' '1.5L I3 Ecoboost' '2.0L EcoBoost? Engine'
#  '2.0L I4 Turbo' '2.0L ECOBOOST' '2.3L I4 Turbo' '2.0L I4 Ecoboost'
#  'TWIN-SCROLL 2.0L ECOBOOST' '5.0L TI-VCT V8' '3.3L V6 PFDI'
#  '3.5L V6 ECOBOOST' '2.7L V6 Twin Turbo' 'Premium Unleaded V-8 5.0 L/302'
#  '3.5L POWERBOOST FULL-HYBRID V6' '2.7L EcoBoost? V6 Engine'
#  '3.5L EcoBoost with Auto Start/Stop Technology Syst'
#  '2.7L EcoBoost with Auto Start/Stop Technology Syst'
#  '5.0L Ti-VCT V8 Engine (470HP)' '3.5L V6 Twin Turbo Hybrid'
#  '3.5L V6 ECOBOOST HIGH OUTPUT'
#  'EcoBoost 1.6L I4 GTDi DOHC Turbocharged VCT'
#  '1.5L I4 16V GDI DOHC Turbo' '2.0L I4' '2.3L' '2.5L HYBRID'
#  '2.5L I4 Hybrid' '1.5L EcoBoost? with Auto Start-Stop Technology'
#  '3.3L PFDI with Flex-Fuel Capability and Auto Start'
#  '2.5L Plug-In Hybrid' '2.7L ECOBOOST V6'
#  '2.3L EcoBoost I-4 Engine with Auto Start-Stop Tech' '3.5L V6 Twin Turbo'
#  '2.7L V6' '5.0L Ti-VCT V8 Engine (450HP)' '2.7L EcoBoost? Engine'
#  'Ecoboost 3.5L V6' '3.0L V6 Twin Turbo'
#  '3.0L EcoBoost? V6 Engine with Auto Start-Stop Tech'
#  'RR PRIMARY & FR SECONDARY ELECTRIC MOTOR (99U)' 'Electric'
#  '2.7L V6 Turbo' '5.2L V8 Supercharged' '5.4L V8 EFI 24V'
#  '1.6L I4 120HP 112FT. LBS.' '5.4L' '2.0L ECOBOOST ENGINE'
#  '1.5L ECOBOOST ENGINE' '5.0L V8 32V PDI DOHC'
#  '3.5L V6 24V PDI DOHC Twin Turbo' '2.0L I4 ECOBOOST ENGINE'
#  '2.3L ECOBOOST ENGINE' '2.3L EcoBoost? Engine' '2.3L ECOBOOST I-4 ENGINE'
#  '3.5L V6 EcoBoost? Engine with Auto Start/Stop Tech'
#  '5.0L V8 with Flex-Fuel Capability' '2.7L ECOBOOST V6 ENGINE'
#  '2.7L EcoBoost? with Auto Start/Stop Technology Sys' '3.3L PFDI ENGINE'
#  '2.7L ECOBOOST ENGINE' '3.5L V6 ECOBOOST ENGINE'
#  '5.0L V8 with Auto Start/Stop Technology and Flex-F'
#  '91kWh Extended Range Battery ? Rear Primary Elect'
#  '3.5L EcoBoost? V6 Engine' '4.6L' 'Gas/Electric I-4 2.5 L/152'
#  '3.5L V6 HYBRID' '3.0L ECOBOOST V6' '2.0L INLINE 4 DOUBLE OVERHEAD'
#  '5.0L V8 460HP 420FT. LBS.' '3.5L DOHC' '3.8L V6 Cylinder Engine'
#  'Twin Turbo Premium Unleaded V-6 3.3 L/204' '3.3L 6cyl' '3.5T'
#  '2.5L I4 16V PDI DOHC Turbo' 'DURAMAX 2.8L TURBO DIESEL' '3.0 L'
#  'DURAMAX 3.0 TURBO-DIESEL' '6.2 L' '228HP 2.0L 4 Cylinder Engine'
#  '2.5L DOHC 4-CYLINDER SIDI' '3.6L V6 288HP 270FT. LBS.'
#  'Turbocharged Gas/E15 I4 1.5L/-TBD-' '4.3L 6cyl' 'EcoTec3 6.2L V8'
#  '4.8 lt.' '137HP 1.6L 4 Cylinder Engine' '5.3L' '5.3L V8'
#  '310HP 3.6L V6 Cylinder Engine' '5.3L ECOTEC3 V8 ENGINE'
#  '3.6L V6 275HP 251FT. LBS.' '1.8L 4cyl'
#  '1.5L 16-Valve 4-Cylinder DOHC i-VTEC -inc: direct'
#  'Intercooled Turbo Premium Unleaded I-4 1.5 L/91'
#  '3.5L V6 SOHC i-VTEC 24V' 'I4 DOHC 16V Turbocharged'
#  '1.5L L4 16V DOHC TURBO' 'Regular Unleaded V-6 3.5 L/212'
#  '1.5L L4 DOHC 16V TURBO' '3.5L V6 SOHC 24V' '3.5L 6cyl.'
#  '3.5L 24-Valve SOHC i-VTEC V6' 'Gas/Electric I-4 1.5 L/91' 'YF6H6MKNY'
#  '1.5L I-4 DOHC 16-Valve Turbocharged' '1.5L I4 F DOHC 16V'
#  '2.0L I-4 DOHC 16-Valve i-VTEC -inc: Port injection'
#  'Regular Unleaded I-4 1.8 L/110' '2.0L I-4 DOHC 16-Valve i-VTEC'
#  '4 Cylinder Engine 1.7L' '1.8L' '1.8L I4' '1.3'
#  '140HP 1.8L 4 Cylinder Engine'
#  '2.0T I-4 DOHC 16-Valve Turbocharged i-VTEC'
#  '280HP 3.5L V6 Cylinder Engine'
#  '1.5L I4 Turbocharged DOHC 16V LEV3-ULEV50 190hp'
#  '1.5L 16-Valve DOHC Turbocharged 4-Cylinder'
#  '1.5L I4 Turbocharged DOHC 16V LEV3-ULEV50 180hp' '1.5 L Inline4'
#  '2.0L I4 DOHC 16V' '190HP 2.4L 4 Cylinder Engine'
#  '1.8L I4 SOHC 16V i-VTEC' '1.5L I4 DOHC 16V' '2.0L I4 DOHC 16V i-VTEC'
#  '1.5L Turbocharged' '1.8L I4 140HP 128FT. LBS.'
#  '2.4L I4 180HP 161FT. LBS.' '2.4L I4 185HP 181FT. LBS.' '1.5-Liter TURBO'
#  '2.4 4cyl' '1.5T' '1.5L I4 Turbocharged DOHC 16V LEV3-ULEV70 190hp'
#  '1.8 4 CYL' '2.4L I4 177HP 161FT. LBS.' '1.8L 4 CYL' '1.8L 140.0hp'
#  '4 cylinder' '1.5L I4 130HP 114FT. LBS.' '1L NA I4 SINGLE OVERHEAD CAM ('
#  '189.0hp' '3.5L 248.0hp' '2.4L 4-Cyl Engine'
#  '1.6L Turbo GDI I4 16v DOHC Engine'
#  '1.6L I4 DGI Turbocharged DOHC 16V LEV3-ULEV70 201h'
#  '2.4L GDI I4 DOHC -inc: single exhaust and Dual Con'
#  'V6 Cylinder Engine 3.3L'
#  '2.5L GDI MPI DOHC I4 CVVT -inc: engine idle stop a'
#  '3.3L V6 Cylinder Engine' '2.4 litre' '2.0 litre' 'KONA ULTIMATE'
#  'Intercooled Turbo Gas/Electric I-4 1.6 L/98' '2.0L L4 16V DOHC'
#  '2.0L GDI I4 16V DOHC' '1.6 LITRE' '4 Cylinder Engine 1.6L' '1.6L I4'
#  '3.8L V6' '3.8 litre' '185HP 2.4L 4 Cylinder Engine'
#  'Gas/Electric I-4 1.6 L/96' 'EL74IF20A200' '2.0L 4-Cylinder DOHC 16V'
#  '290HP 3.3L V6 Cylinder Engine' '240HP 2.0L 4 Cylinder Engine'
#  '2.4L I4 DGI DOHC 16V' '1.6L I4 137HP 123FT. LBS.'
#  '1.8L I4 145HP 130FT. LBS.' '164HP 2.0L 4 Cylinder Engine'
#  'V6 Cylinder Engine 3.8L'
#  '1.6L Turbo GDI DOHC 16-Valve I4 w/CVVD -inc: idle'
#  '2.4L I4 175HP 168FT. LBS.' '1.6L I4 138HP 123FT. LBS.'
#  '1.8L I4 148HP 131FT. LBS.' '2.4L I4 185HP 178FT. LBS.' '1.8L 148.0hp'
#  '3.3L' '175HP 1.6L 4 Cylinder Engine' '2.0L DOHC'
#  '1.6L DPI DOHC 16-Valve I4 CVVT'
#  '1.6L I4 DGI Turbocharged DOHC 16V LEV3-ULEV125 201' '2.5 LITRE'
#  '2.0L Turbo GDI DOHC 4-Cylinder'
#  '2.5L Turbo GDI MPI DOHC 16-Valve I4 CVVT' '2.0L I4 173HP 154FT. LBS.'
#  '1.6L' '2.4 L 4CYL' '147HP 2.0L 4 Cylinder Engine'
#  '164HP 1.6L 4 Cylinder Engine' '226HP 1.6L 4 Cylinder Engine' '2.4l'
#  '1.6 L' '6 CYL' '5.6L 8cyl.' '8 Cylinder Engine 5.6L' '3.7L V6 DOHC 24V'
#  '5.6L 8cyl' '5.6L V8 with VVEL and DIG' '5.6' ': 5.6L V8 w/VVEL DIG'
#  '3.7L V6 SMPI DOHC' '5.6L V8 32V GDI DOHC' '5.6L V8 DOHC 32V'
#  '3.7L V6 DOHC' '3.5L 306.0hp' '2.0L I4 16V GDI DOHC Turbo'
#  '180HP 2.0L 4 Cylinder Engine' '5.0L V8 Supercharged' '3 L'
#  '3.0L V6 DOHC 24V SUP'
#  'Intercooled Supercharger Premium Unleaded V-8 5.0'
#  '2.0L DOHC I-4 DI Turbo PHEV' '3.2L V6' 'V6 Cylinder Engine 3.2L'
#  '2.4L I4' '3.2L 6cyl' 'Regular Unleaded V-6 3.2 L/198' '6.4L V8'
#  '3.6L V6 Cylinder Engine' '3.2L Pentastar VVT V6 w/ESS'
#  '2.0L DOHC I-4 DI Turbo w/ESS' '5.7L V-8 engine'
#  '2.4L MultiAir I-4 Zero Evap w/ESS' '2.4L 4 Cylinder'
#  '3.6L Pentastar VVT V6 w/eTorque' '5.7L VVT V8 w/FuelSaver MDS'
#  '3.0L V6 Turbodiesel' '2.0L Turbo 4 Cylinder'
#  '3.0L I-6 Hurricane SO Twin Turbo ESS' '3.2L V6 DOHC 24V'
#  '240HP 3.0L V6 Cylinder Engine' '271HP 3.2L V6 Cylinder Engine'
#  '295HP 3.6L V6 Cylinder Engine' '3.6L V6 DOHC 24V FFV'
#  '3.2L PENTASTAR VVT V6 W/ESS' '3.6L 6 Cyl.' 'I-4' '2.4L I4 SFI DO'
#  '2.4L I4 16V MPFI SOHC' '3.2L V6 24V MPFI DOHC' '5.7L HEMI V8'
#  'Gas w/ eTorque V-6 3.6 L/220' '2.0L I4 16V GDI DOHC Turbo Hybrid'
#  '6.4L V8 16V MPFI OHV' 'Twin Turbo Premium Unleaded I-6 3.0 L/183'
#  '3.0L I6 Hurricane HO Twin Turbo ESS' 'pentastar 3.6'
#  '2.5L Turbo GDI 4-Cylinder DOHC D-CVVT -inc: Igniti'
#  '3.3L Twin-Turbo GDI V6'
#  '2.0L MPI DOHC I4 W/D-CVVT -INC: IDLE STOP AND GO'
#  '2.0L I4 MPI DOHC 16V LEV3-SULEV30 147hp'
#  '1.6L Turbo GDI 4 Cyl DOHC D-CVVT' '2.0L MPI 4-Cylinder'
#  '2.0L MPI I4 -inc: idle stop and go' 'SP757L' 'Gas I4 2.0L/121'
#  'Regular Unleaded V-6 3.8 L/231' '2.0L MPI 4 CYL DOHC 16V D-CVVT'
#  '2.4L I4 DGI DOHC' '1.6L turbo GDI' 'Regular Unleaded V-6 3.3 L/204'
#  '2.0L GDI 4 Cyl DOHC 16V D-CVVT' '1.6L Turbo GDI DOHC I4 CVVD'
#  '261HP 1.6L 4 Cylinder Engine' '120HP 1.6L 4 Cylinder Engine'
#  '1.6L MPI DOHC 16-VALVE D-CVVT 4-CYLINDER' '146HP 2.0L 4 Cylinder Engine'
#  '1.6L T-GDI DOHC I4 W/D-CVVT -INC: IDLE STOP AND GO'
#  '290HP 3.5L V6 Cylinder Engine' '290HP 2.5L 4 Cylinder Engine'
#  '281HP 2.5L 4 Cylinder Engine' '368HP 3.3L V6 Cylinder Engine' '2.0 L'
#  '2.0L I4 MPI DOHC 16V LEV3-ULEV70 147hp' '181HP 2.4L 4 Cylinder Engine'
#  '2.4 L Inline4' '3.3 L V6'
#  '2.5L I4 DGI Turbocharged DOHC 16V LEV3-ULEV70 281h'
#  '2.0L I4 164HP 151FT. LBS.' '2.4L I4 16V GDI DOHC' 'SKW52G61VGG492'
#  '2.0 L Inline4' '2.0L I4 MPI' 'HYW6L9G1NGG015'
#  '145HP 1.8L 4 Cylinder Engine' '2.4L I-4 DOHC 16 Valve CVVT'
#  '2.4L DOHC GDI I4' '1.6 L Inline4'
#  '2.5L TURBO GDI 4-CYLINDER DOHC D-CVVT -INC: IGNITI' '3.3L TURBO 6cyl.'
#  '3.8L V6 244HP 253FT. LBS.' '2.4L I4 173HP 168FT. LBS.'
#  '2.0L I4 156HP 144FT. LBS.' '1.6L TURBO 4cyl.' '3.3L V6 DGI'
#  '3.3L TWIN-TURBO GDI V6 DOHC D-CVVT -INC: IDLE STOP' '3.8L 6cyl.' '5.0L'
#  '5.2L' '6.5L' '641HP 4.0L 8 Cylinder Engine' 'V10' '2.5L I4 16V GDI DOHC'
#  'Intercooled Turbo Premium Unleaded I-4 1.6 L/99'
#  '1.6L 4-Cylinder DOHC 16V' '260HP 3.5L V6 Cylinder Engine' '2.5L I4'
#  '5.6L V8' '2.5L I4 F DOHC 16V' '2.5L 4-Cylinder DOHC 16V'
#  'Regular Unleaded I-4 1.6 L/98' '1.6L L4 DOHC 16V TURBO'
#  '2.5L DOHC 16-Valve 4-Cyl Engine'
#  '3.5L DOHC 24V V6 -inc: remote engine start' '2.0L I4 16V MPFI DOHC'
#  '3.5L V6 DOHC' '3.8L Twin Turbo V6 - 600 hp' '2.0L DOHC 16V 4-Cylinder'
#  '4.0L V6 24V MPFI DOHC' '3.5L V6 24V MPFI DOHC'
#  '1.8L I4 130HP 128FT. LBS.' '2.5L I4 182HP 180FT. LBS.' '2.5 L'
#  '2.5L 170.0hp' '170HP 2.5L 4 Cylinder Engine' '1.6L I4 109HP 107FT. LBS.'
#  '2.5L I4 175HP 180FT. LBS.' '2.0L I4 140HP 147FT. LBS.' '4.0V6'
#  '1.6L 4cyl.' '2.0L I4 16V GDI DOHC' '3.5L V6 290HP 261FT. LBS.' '4L'
#  '1.6L DOHC 16V 4-Cylinder' '1.8L I4 122HP 127FT. LBS.' '6.6L'
#  'Twin Turbo Premium Unleaded V-12' '6.6' 'V12' '2.5L 5cyl'
#  'Intercooled Turbo Regular Unleaded I-4 1.8 L/110'
#  'Intercooled Turbo Regular Unleaded I-4 1.4 L/85' '3.0L TDI'
#  '1.5-TSI 4-Cylinder' '1.4L I4' '3.6L FSI 276 HP 6-Cylinder' 'A342P6'
#  '2.0L TSI 235 HP' '2L I4 F DOHC 16V' '2.0L TSI 184HP' '1.8L L4'
#  '1.4L TSI' '2.0L Inline4 Turbo' '2.0L TSI' '3.6L V6 280HP 265FT. LBS.'
#  '1.9L' '3.0L V6 24V DDI DOHC Turbo Diesel' '1.4L Inline4 Turbo'
#  '2.0L I4 115HP 125FT. LBS.' '1.4L TURBO I4 150HP 184FT. LBS'
#  '1.8L TURBO I4 170HP 184FT. LBS' '1.5 L/91' '2.0 L/121' '1.5L 4cyl.'
#  '3.6 L/220' '5 CYL' '2.5L I5 170HP 177FT. LBS.'
#  '3.6L V6 280HP 258FT. LBS.' '2.0L TDI' '2.5L I5 150HP 170FT. LBS.'
#  '2.0L 150.0hp' '2.0L 140.0hp']
# Drivetrain: ['AWD' 'FWD' 'RWD' nan '4x4' '4WD' '2WD']
# Doors: [nan '4' '2' '5' '3']
# Fuel Type: ['Gas' 'Premium Unleaded' 'Diesel' 'Gasoline Hybrid' 'Gas/Electric Hybrid'
#  'Other' 'Flexible' 'Electric' 'Regular Unleaded' 'Gasoline Fuel'
#  'Gaseous Fuel Compatible']

# %%
df['Doors'] = df['Doors'].astype(float)

# %%
# Loop over each column in the DataFrame where dtype is 'object'
for col in df.select_dtypes(include=['object']).columns:
    
    # Initialize a LabelEncoder object
    label_encoder = LabelEncoder()
    
    # Fit the encoder to the unique values in the column
    label_encoder.fit(df[col].unique())
    
    # Transform the column using the encoder
    df[col] = label_encoder.transform(df[col])
    
    # Print the column name and the unique encoded values
    print(f"{col}: {df[col].unique()}")
# Out:
# Make: [0 2 1 4 3]
# Model: [3 5 6 7 2 4 1 0]
# Body Type: [ 6  7  2  4 11  5  9  1  3  0 10  8]
# Engine: [928 169 575 473 477 824 934 681 277 471 583 855 920 494 803 678 164 581
#  856 930 503 269 545 547 147  95 582 279 573 378 485 486 311 452 252 375
#  805 574 225 712 823 165 403 426 729 168 411 433 812 413 379 810 834 402
#    0 156 827 844 115 625 626 590 594 373 929 816 711 912 938 153 442 427
#  434 595 570 569 443 227 377 939 113 596 226 841 241 708 343 436 444 441
#  249 410 588 428 437 211 400 921  96 116 940 117 925 713 587 683 684 307
#  157 896 445 248 440 429 895 166 897 155 601 804 423 424 714 814 220 604
#  815 602 918 734 603 605 845 247 405 174 447 114 826 572 591 615 420 388
#  422 888 562 414 607 419 606 682 846 163 608 412 170 240 571  15 781 576
#  126 511 901 516 756 274   7  17 755 757   9 686 384 695 245 784 721 690
#  609 536 246 698 353 517 219 526  11 649 902 779 782 905 577 801 935 926
#  363 745 646 710  14 597  61 619 775 518 519 933 580  19  23 776 907   8
#  128 132 564 653 566 783 563 903 617  35 540 760 296  12 125 651  33 514
#  543 655 767 648  16  13 243 645  28 352 366 364 365 692 780 758  60 904
#  709 650 362 691 529 685 671  62  10 535 951 759 600 160 544 688   4 875
#  522 524 589 528 512 523 542 527 291 611 560 430 618 614 469 773 716 913
#  376 374 551 909 218 772 553 470 539 568 554 317 348 936 124 799 346 798
#  399 314 141 850 747 342 884 140 847 584 870 797 807 849 860 381 318 859
#  837 137 839 127   1 796 889 892 893 749 944 848 945 740 851 891 750 890
#  748 347 732 795 345 268 546 883 149 332 193 882 145 329 881 915 659 715
#  208 942 237 900 203 622 613 204 794 612 660 739 718 741 879 946 742 251
#  585 947 809 661 793 662 623 917 894 941 854 818 238 407 811  65  31  73
#   71 906  94 820 136 404  59  70 280   5 831 869 315 949 304 206 305 288
#  195 406 177  36 284 324 283 194 275 161 302 790 185 313 865 828 321 774
#  187 864 134 171 281 320 186 162 817 326 308 674 537 720 725 887 689 840
#  673 700 701 488 791 792 454 923 878 722 723 670 852 927 394 541 853 521
#  694 697 680 886 724 676 489 822 877 693 472 727 858 696 699 599 916 561
#  737 383 180  32  47 354 868 832 731  39  57 753 874 788 778 257 630 763
#  752 751 266 642 730 862 717 771 487 640 182  42 825 728 507 254  44 633
#  836 835 484   2 843 829 216 733 656  55 463 620 735 863 950 628 152   3
#  919 258 417 746 754 260 387 239 765 255 766 467 458 636 264 370  37 500
#  256 368 369 432 762 492 643 333 212 222 502 842  84 899 233 142 496  40
#  265 341  46  45 181 217 178 267 210 898 629 468 497 372 857 483 360 481
#  358 632 509 499 764  49 190 253 327 338  41 460 344 356 262 508 367 631
#  359 769 439 416 861 770 371 644 658  79 657 179  38 634 491 209 259 263
#  261 501 639 357 361 459 355 498 638 726 482 610 789 504 415 221 635 479
#  559 914 457 510 331 743 409 744 687 382 323 533 908 598 768 616 119 647
#  654 565 652 530 102  29 819 506 806  56 873  58 505 478 474 786 943  43
#   51 189 867 188 579  98 103   6 120 250 392  53  30  52  24 205 144 109
#   50 207  63 106 295 298  26 270  64  54  97 294 101  99 586  48 146 143
#  475 278  92  83 285 932 325 465 273 154 838 813 224 184  68 578  77 557
#  552 139 787 761 167 396 385 300  80 107 130 937  90 293  81 108 297 100
#  456 133 172  76  82 310 244 351 202  69 271 123 129 380 306  66 679 665
#  719 549 664 669 663 736 550 667 668 548 476 199 135 637 408 435 808 175
#  450 931 287 446 871 702 534 449 176 675 303 276 525 677 438 242 418 453
#  386 391 398 538 448 515 802 301 290 451 672 785 200 703 910 421 948 350
#  464 230 214  89 229 231 885 777 876 228 299  93 872 183  91 390 118  86
#  122  87 397 395 393 567 148 215 138 272 455 336 197 289 880 150 213 800
#  121 286 282  67 349 461 558 292 196  88 466 462 555 627 641 704 707 922
#  330 821  72 389 328 666 337 316 866  85 322 480 201 495 556 173 592 490
#  105 335 309 312 131  78 334 192 593  74 198 493 621  75 104 706 911 705
#  924 319 833 830 425  27  18 520 738 236 401 235 110  21 223 234 532 112
#  431  20 191  22 111  25 151  34 513 624 340 531 232 339 159 158]
# Drivetrain: [3 4 5 6 2 1 0]
# Fuel Type: [ 3  9  0  7  4  8  2  1 10  6  5]

# %%
df.dtypes
# Out:
# Year            int64
# Make            int32
# Model           int32
# Kilometres      int32
# Body Type       int32
# Engine          int32
# Drivetrain      int32
# Passengers    float64
# Doors         float64
# Fuel Type       int32
# City          float64
# Highway       float64
# Price           int64
# dtype: object

# %%
from scipy import stats

# define a function to remove outliers using z-score for only selected numerical columns
def remove_outliers(df, cols, threshold=3):
    # loop over each selected column
    for col in cols:
        # calculate z-score for each data point in selected column
        z = np.abs(stats.zscore(df[col]))
        # remove rows with z-score greater than threshold in selected column
        df = df[(z < threshold) | (df[col].isnull())]
    return df

# %%
selected_cols = ['City', 'Highway']
df_clean = remove_outliers(df, selected_cols)
df_clean.shape
# Out:
# (17431, 13)

# %%
df.shape
# Out:
# (17662, 13)

# %%
#Correlation Heatmap
plt.figure(figsize=(20, 16))
sns.heatmap(df_clean.corr(), fmt='.2g', annot=True)
# Out:
# <Axes: >

# %%
X = df_clean.drop('Price', axis=1)
y = df_clean['Price']

# %%
#test size 20% and train size 80%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=0)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV

dtree = DecisionTreeRegressor()

param_grid = {
    'max_depth': [2, 4, 6, 8],
    'min_samples_split': [2, 4, 6, 8],
    'min_samples_leaf': [1, 2, 3, 4],
    'max_features': ['sqrt', 'log2', None]
}

grid_search = GridSearchCV(dtree, param_grid, cv=5, scoring='neg_mean_squared_error')

grid_search.fit(X_train, y_train)

print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'max_depth': 8, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2}

# %%
from sklearn.tree import DecisionTreeRegressor
dtree = DecisionTreeRegressor(random_state=0, max_depth=8, max_features='log2', min_samples_leaf=4, min_samples_split=8)
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=8, max_features='log2', min_samples_leaf=4,
#                       min_samples_split=8, random_state=0)

# %%
from sklearn import metrics
from sklearn.metrics import mean_absolute_percentage_error
import math
y_pred = dtree.predict(X_test)
mae = metrics.mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
rmse = math.sqrt(mse)

print('MAE is {}'.format(mae))
print('MAPE is {}'.format(mape))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
print('RMSE score is {}'.format(rmse))
# Out:
# MAE is 8664.467436241306
# MAPE is 0.23384982231269338
# MSE is 361892771.8863338
# R2 score is 0.7126272225081058
# RMSE score is 19023.47948947126

# %%
imp_df = pd.DataFrame({
    "Feature Name": X_train.columns,
    "Importance": dtree.feature_importances_
})
fi = imp_df.sort_values(by="Importance", ascending=False)

fi2 = fi.head(10)
plt.figure(figsize=(10,8))
sns.barplot(data=fi2, x='Importance', y='Feature Name')
plt.title('Feature Importance Each Attributes (Decision Tree Regressor)', fontsize=18)
plt.xlabel ('Importance', fontsize=16)
plt.ylabel ('Feature Name', fontsize=16)
plt.show()

# %%
import shap
import matplotlib.pyplot as plt

# Use the best estimator from GridSearchCV
best_model = grid_search.best_estimator_

# Initialize SHAP TreeExplainer
explainer = shap.Explainer(best_model, X_train)  # Automatically picks the right explainer type

# Calculate SHAP values for the test set
shap_values = explainer(X_test)

# Summary plot of feature importances
shap.summary_plot(shap_values, X_test)

# %%
explainer = shap.Explainer(dtree, X_test)
shap_values = explainer(X_test)
shap.plots.waterfall(shap_values[0])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Create a Random Forest Regressor object
rf = RandomForestRegressor()

# Define the hyperparameter grid
param_grid = {
    'max_depth': [3, 5, 7, 9],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt']
}
# Create a GridSearchCV object
grid_search = GridSearchCV(rf, param_grid, cv=5, scoring='r2')

# Fit the GridSearchCV object to the training data
grid_search.fit(X_train, y_train)

# Print the best hyperparameters
print("Best hyperparameters: ", grid_search.best_params_)
# Out:
# C:\Users\Admin\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 180 fits failed out of a total of 360.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\Anaconda\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\Anaconda\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Admin\Anaconda\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Admin\Anaconda\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Admin\Anaconda\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.54302519 0.54476461 0.54200608
#  0.54791642 0.54999223 0.54548502 0.54193963 0.54296616 0.54248042
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.70847487 0.70941445 0.70872724
#  0.70917908 0.70599971 0.70402371 0.70149505 0.70280716 0.69971048
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.80448704 0.79589694 0.79081242
#  0.79009302 0.79189595 0.78547818 0.77463342 0.77281629 0.77112615
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.84365679 0.84559612 0.83253002
#  0.83575776 0.83505686 0.82381343 0.80680238 0.81319    0.80611202]
#   warnings.warn(
# Best hyperparameters:  {'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5}

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(random_state=0, max_depth=9, min_samples_split=2, min_samples_leaf=1, 
                           max_features='sqrt')
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=9, max_features='sqrt', random_state=0)

# %%
from sklearn import metrics
from sklearn.metrics import mean_absolute_percentage_error
import math
y_pred = rf.predict(X_test)
mae = metrics.mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
rmse = math.sqrt(mse)

print('MAE is {}'.format(mae))
print('MAPE is {}'.format(mape))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
print('RMSE score is {}'.format(rmse))
# Out:
# MAE is 6130.076415980691
# MAPE is 0.1656263424905641
# MSE is 204142736.63390535
# R2 score is 0.8378937912313219
# RMSE score is 14287.852764985555

# %%
imp_df = pd.DataFrame({
    "Feature Name": X_train.columns,
    "Importance": dtree.feature_importances_
})
fi = imp_df.sort_values(by="Importance", ascending=False)

fi2 = fi.head(10)
plt.figure(figsize=(10,8))
sns.barplot(data=fi2, x='Importance', y='Feature Name')
plt.title('Feature Importance Each Attributes (Random Forest Regressor)', fontsize=18)
plt.xlabel ('Importance', fontsize=16)
plt.ylabel ('Feature Name', fontsize=16)
plt.show()

# %%
import shap
explainer = shap.TreeExplainer(rf)
shap_values = explainer.shap_values(X_test)
shap.summary_plot(shap_values, X_test)

# %%
import shap

# Use TreeExplainer
explainer = shap.TreeExplainer(rf)

# Disable additivity check here
shap_values = explainer(X_test, check_additivity=False)

# Plot waterfall plot
shap.plots.waterfall(shap_values[0])

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import GridSearchCV

# Define AdaBoostRegressor model
abr = AdaBoostRegressor()

# Define hyperparameters and possible values
params = {'n_estimators': [50, 100, 150],
          'learning_rate': [0.01, 0.1, 1, 10]}

X_train_clean = X_train.dropna()
y_train_clean = y_train[X_train_clean.index]


# Perform GridSearchCV with 5-fold cross validation
grid_search = GridSearchCV(abr, param_grid=params, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train_clean, y_train_clean)

# Print best hyperparameters and corresponding score
print("Best hyperparameters: ", grid_search.best_params_)
# Out:
# Best hyperparameters:  {'learning_rate': 0.1, 'n_estimators': 50}

# %%
from sklearn.ensemble import RandomForestRegressor
abr = AdaBoostRegressor(random_state=0, learning_rate=0.1, n_estimators=50)
abr.fit(X_train_clean, y_train_clean)
# Out:
# AdaBoostRegressor(learning_rate=0.1, random_state=0)

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.metrics import mean_absolute_percentage_error
import math

# Define pipeline
pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='mean')),  # handles NaNs
    ('abr', AdaBoostRegressor())
])

# Define hyperparameter grid (use pipeline step name)
params = {
    'abr__n_estimators': [50, 100, 150],
    'abr__learning_rate': [0.01, 0.1, 1, 10]
}

# GridSearchCV
grid_search = GridSearchCV(pipeline, param_grid=params, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

# ✅ Now this handles missing values in X_test automatically
y_pred = grid_search.predict(X_test)

# Evaluation
mae = metrics.mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
r2 = metrics.r2_score(y_test, y_pred)
rmse = math.sqrt(mse)

print('MAE is {}'.format(mae))
print('MAPE is {}'.format(mape))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
print('RMSE score is {}'.format(rmse))
# Out:
# MAE is 13808.951374841165
# MAPE is 0.5043646533832066
# MSE is 491757885.4821589
# R2 score is 0.6095035867449294
# RMSE score is 22175.614658497267

# %%
imp_df = pd.DataFrame({
    "Feature Name": X_train.columns,
    "Importance": abr.feature_importances_
})
fi = imp_df.sort_values(by="Importance", ascending=False)

fi2 = fi.head(10)
plt.figure(figsize=(10,8))
sns.barplot(data=fi2, x='Importance', y='Feature Name')
plt.title('Feature Importance Each Attributes (AdaBoost Regressor)', fontsize=18)
plt.xlabel ('Importance', fontsize=16)
plt.ylabel ('Feature Name', fontsize=16)
plt.show()
